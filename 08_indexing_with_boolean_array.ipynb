# %% [markdown]
# # Indexing Using Boolean array

# %%
import numpy as np

# %%
arr = np.random.randint(low=1,high=100,size=10).reshape(2,5)
arr
# Out:
# array([[93, 27, 79, 61, 50],
#        [58,  7, 93, 28, 11]], dtype=int32)

# %%
# Indexing using Boolean array
arr[(arr>50) & (arr%2!=0)]
# Out:
# array([93, 79, 61, 93], dtype=int32)
