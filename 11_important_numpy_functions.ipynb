# %% [markdown]
# # Some important Numpy functions

# %%
import numpy as np

# %%
np.random.random()
# Out:
# 0.05952449697569773

# %%
np.random.seed(1)
np.random.random()
# Out:
# 0.417022004702574

# %%
np.random.uniform(3,11)
# Out:
# 5.418660581054718

# %%
np.random.uniform(1,100,10)
# np.random.uniform(1,100,10).reshape(2,5)
# Out:
# array([[69.49583428, 32.23604747, 68.96359184, 83.62794152,  2.81053946],
#        [75.26428718, 98.8972478 , 75.06839978, 28.76395521, 79.13865352]])

# %%
np.random.randint(1,10,5)
# Out:
# array([9, 7, 4, 8, 8], dtype=int32)

# %%
np.random.randint(1,10,15).reshape(3,5)
# Out:
# array([[2, 2, 4, 1, 9],
#        [7, 5, 6, 7, 3],
#        [6, 8, 9, 5, 5]], dtype=int32)

# %%
a = np.random.randint(1,10,6)
a
# Out:
# array([8, 8, 5, 1, 3, 1], dtype=int32)

# %%
np.max(a)
# Out:
# np.int32(8)

# %%
np.min(a)
# Out:
# np.int32(1)

# %%
np.argmax(a)
# Out:
# np.int64(0)

# %%
a[np.argmax(a)]
# Out:
# np.int32(8)

# %%
a[np.argmin(a)]
# Out:
# np.int32(1)

# %%
np.argmin(a)
# Out:
# np.int64(3)

# %%
a=np.random.randint(1,10,6)
a
# Out:
# array([6, 2, 3, 2, 6, 5], dtype=int32)

# %%
a[a%2 == 1] = -1
a
# Out:
# array([ 6,  2, -1,  2,  6, -1], dtype=int32)

# %%
# where(condition,True,false)

# %%
a = np.random.randint(1,50,6)
a
# Out:
# array([ 7, 14, 16, 25, 10,  3], dtype=int32)

# %%
np.where(a%2 == 1 , -1 , a )
# Out:
# array([-1, 14, 16, -1, 10, -1], dtype=int32)

# %%
out = np.where(a%2==1 , -1 , a)
out
# Out:
# array([-1, 14, 16, -1, 10, -1], dtype=int32)

# %%
a = np.random.randint(1,50,10)
a
# Out:
# array([41, 15, 46, 24, 17, 29, 43, 46,  4,  3], dtype=int32)

# %%
b = np.sort(a)
b
# Out:
# array([ 3,  4, 15, 17, 24, 29, 41, 43, 46, 46], dtype=int32)

# %%
np.percentile(a,25)
# Out:
# np.float64(15.5)

# %%
np.percentile(a,50)
# Out:
# np.float64(26.5)

# %%
np.percentile(a,99.8)
# Out:
# np.float64(46.0)
