# %% [markdown]
# # Properties & Attributes
#
# 1. Shape
# 2. nDim
# 3. Size
# 4. Itemsize
# 5. Dtype
# 6. astype()

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5])
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
arr2 = np.array([[1,1,1,1],[2,2,2,2]])
arr2
# Out:
# array([[1, 1, 1, 1],
#        [2, 2, 2, 2]])

# %%
arr3 = np.array([[[1,2,3]],[[2,3,4]],[[3,4,5]]])
arr3
# Out:
# array([[[1, 2, 3]],
#
#        [[2, 3, 4]],
#
#        [[3, 4, 5]]])

# %%
arr4 = np.zeros((2,3))
arr4
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
arr5 = np.ones((3,3))
arr5
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %% [markdown]
# # To find the shape of the array

# %%
print(arr1.shape)
print(arr2.shape)
print(arr3.shape)
# Out:
# (5,)
# (2, 4)
# (1, 3, 3)

# %%
arr2.shape
# Out:
# (2, 4)

# %%
arr3.shape
# Out:
# (1, 3, 3)

# %% [markdown]
# # To find the dimension of array

# %%
print(arr1.ndim)
print(arr2.ndim)
print(arr3.ndim)
# Out:
# 1
# 2
# 3

# %% [markdown]
# # To find the size of array

# %%
arr1.size
# Out:
# 5

# %%
arr2.size
# Out:
# 8

# %%
arr3.size
# Out:
# 9

# %%
arr4.size
# Out:
# 6

# %% [markdown]
# # Difference between size and itemsize
# 1. size → Total number of elements
#
# It tells you how many elements are present in the array.
#
# 2. itemsize → Memory occupied by each element
#
# It tells you how many bytes one element occupies.

# %% [markdown]
# # To find the itemsize of the array

# %%
arr4.itemsize
# Out:
# 8

# %%
arr3.itemsize
# Out:
# 8

# %% [markdown]
# # To find the datatype of an array

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
arr4.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # To change  the type of an array

# %%
arr4
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
arr4.astype('int')
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
arr3
# Out:
# array([[[1, 2, 3]],
#
#        [[2, 3, 4]],
#
#        [[3, 4, 5]]])

# %%
arr3.astype('float')
# Out:
# array([[[1., 2., 3.]],
#
#        [[2., 3., 4.]],
#
#        [[3., 4., 5.]]])
