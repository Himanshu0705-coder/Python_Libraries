# %% [markdown]
# # Numpy Operations

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5,6])
arr2 = np.array([4,5,6,7,8,9])

# %%
arr1-arr2
# Out:
# array([-3, -3, -3, -3, -3, -3])

# %%
arr1 * arr2       # vector multiplication
# Out:
# array([ 4, 10, 18, 28, 40, 54])

# %%
arr1 * 2       # scaler multiplication
# Out:
# array([ 2,  4,  6,  8, 10, 12])

# %%
arr2 > 5
# Out:
# array([False, False,  True,  True,  True,  True])

# %%
arr3 = np.arange(6).reshape(2,3)
arr4 = np.arange(6,12).reshape(3,2)

# %%
arr4.dot(arr3)     # this 'dot' function multiply the elements
arr3.dot(arr4)
# Out:
# [[21 34 47]
#  [27 44 61]
#  [33 54 75]]
# [[ 28  31]
#  [100 112]]

# %%
arr4.max()
# Out:
# np.int64(11)

# %%
arr4.min()
# Out:
# np.int64(6)

# %%
arr4
# Out:
# array([[ 6,  7],
#        [ 8,  9],
#        [10, 11]])

# %%
arr4.min(axis=0)
# Out:
# array([6, 7])

# %%
arr4.min(axis=1)
# Out:
# array([ 6,  8, 10])

# %%
arr4.sum()
# Out:
# np.int64(51)

# %%
arr4.sum(axis=0)
# Out:
# array([24, 27])

# %%
arr4.mean()
# Out:
# np.float64(8.5)

# %%
# there is no functions median and mode in the Numpy
arr4.median()
arr4.mode()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 arr4.median()
#       2 arr4.mode()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
#  std -- standard deviation
arr4.std()
# Out:
# np.float64(1.707825127659933)

# %%
np.sin(arr4)
# Out:
# array([[-0.2794155 ,  0.6569866 ],
#        [ 0.98935825,  0.41211849],
#        [-0.54402111, -0.99999021]])

# %%
np.mean(arr4)
# Out:
# np.float64(8.5)

# %%
np.median(arr4)
# Out:
# np.float64(8.5)

# %%
np.exp(arr4)
# Out:
# array([[  403.42879349,  1096.63315843],
#        [ 2980.95798704,  8103.08392758],
#        [22026.46579481, 59874.1417152 ]])
