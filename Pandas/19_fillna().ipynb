# %% [markdown]
# # filling missing values using fillna()

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Datasets/matches.csv')

# %%
#  fillna method
df.fillna(0)

# %%
df['column_name'].fillna("value that you want to fill")

# %%
df['column_name'].fillna(method='ffill')
df['column_name'].fillna(method='bfill')
