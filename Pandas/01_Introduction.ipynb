# %% [markdown]
# # Pandas
# In computer programming, pandas is a software library written for the python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.

# %% [markdown]
# # Pandas main Data-structures
# 1. Dataframes
# 2. Series

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\panch\AppData\Roaming\Python\Python314\site-packages (3.0.6)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\panch\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\panch\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\panch\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.4)
# Requirement already satisfied: six>=1.5 in C:\Users\panch\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import pandas library
import numpy as np
import pandas as pd
