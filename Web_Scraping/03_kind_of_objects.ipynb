# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
import requests

# %%
web = requests.get('https://www.wscubetech.com/')
web
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="viewport" content="initial-scale=1.0, width=device-width"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="stylesheet" href="/_next/static/css/0bb41860bda823af.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/628779d13563f190.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/e7f6f1cdcd818262.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/8cb7b7335a3a053c.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-0aabb03b8344b3d6.js"/><script src="/_next/static/chunks/fd9d1056-6f4a001df26bd3d5.js" async=""></script><script src="/_next/static/chunks/7023-c02abf1b325e8331.js" async=""></script><script src="/_next/static/chunks/main-app-55bbd77d79f9187f.js" async=""></script><script src="/_next/static/chunks/13b76428-3a27edfd28c29f16.js" async=""></script><script src="/_next/static/chunks/870fdd6f-22711ca73e9ce48a.js" async=""></script><script src="/_next/static/chunks/aaea2bcf-ac1e4c598ac1115c.js" async=""></script><script src="/_next/static/chunks/69b09407-69006f1471a14c8b.js" async=""></script><script src="/_next/static/chunks/8173-f78e64cf3ff15bed.js" async=""></script><script src="/_next/static/chunks/231-601727ca8ccadf3a.js" async=""></script><script src="/_next/static/chunks/5301-b82a5f7b91b0094b.js" async=""></script><script src="/_next/static/chunks/1170-8492a58d91125314.js" async=""></script><script src="/_next/static/chunks/1232-875777db31fa6c13.js" async=""></script><script src="/_next/static/chunks/661-b8a309bacf0d3fee.js" async=""></script><script src="/_next/static/chunks/6920-e5bb9f3f41bd5fb1.js" async=""></script><script src="/_next/static/chunks/9589-d466380df4176dbb.js" async=""></script><script src="/_next/static/chunks/6474-dcd34a28ef6504c6.js" async=""></script><script src="/_next/static/chunks/3463-6d2676f3b74b354b.js" async=""></script><script src="/_next/static/chunks/6580-c9fd45efaf19adb4.js" async=""></script><script src="/_next/static/chunks/4443-9f9caae06b52512e.js" async=""></script><script src="/_next/static/chunks/5839-7b6c7a7101086a3b.js" async=""></script><script src="/_next/static/chunks/4048-8f73d5ca51e6a542.js" async=""></script><script src="/_next/static/chunks/9118-c498f085639a9603.js" async=""></script><script src="/_next/static/chunks/4255-3c64d45fb7eb9d2d.js" async=""></script><script src="/_next/static/chunks/2666-5dc0ca817461abc5.js" async=""></script><script src="/_next/static/chunks/3117-da16f3894d61959b.js" async=""></script><script src="/_next/static/chunks/4919-e4d1afa56f216042.js" async=""></script><script src="/_next/static/chunks/app/layout-05de045e55259322.js" async=""></script><script src="/_next/static/chunks/app/not-found-c9d0c767ebbbdd37.js" async=""></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3L0ZF56S68"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-10998233603"></script><script src="/_next/static/chunks/3153-6e9a067002404e99.js" async=""></script><script src="/_next/static/chunks/3210-0ce9c3ece71d053e.js" async=""></script><script src="/_next/static/chunks/app/page-85df5481d7287c45.js" async=""></script><meta property="og:type" content="course"/><link rel="preconnect" href="https://fonts.googleapis.com"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="preload" href="/fonts/Neulis-Regular.otf" as="font" type="font/otf" crossorigin="anonymous"/><title>WsCube Tech: Online Certification Courses &amp; Live Training</title><meta name="description" content="WsCube Tech offers the best job-oriented online certification courses in digital marketing, web/app development, cyber security, data science &amp; more."/><link rel="canonical" hre ...

# %%
soup = BeautifulSoup()

# %%
soup = BeautifulSoup(web.content,'html.parser')

# %% [markdown]
# # Tag

# %%
tag = soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.p
tag
# Out:
# <p class="fs-18 lh-24 fw-400 text-color-1 mb-16">Online Programs</p>

# %%
tag = soup.a
tag
# Out:
# <a class="flex-shrink-0 me-0 position-relative lpt-logo" href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" class="max-w-xl-139 max-w-80" data-nimg="1" decoding="async" height="56" loading="lazy" src=" https://deen3evddmddt.cloudfront.net/static/images/ws-cube-white-logo.svg" style="color:transparent;max-height:56px;height:auto" width="139"/></span></a>

# %%
tag = soup.h1
tag

# %%
tag = soup.h2
tag

# %% [markdown]
# # NavigableString

# %%
tag = soup.p.string
tag
# Out:
# 'Online Programs'

# %%
tag = soup.a.string
tag

# %%
tag = soup.h1.string
tag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tag = soup.h1.string
#       2 tag
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %% [markdown]
# # BeautifulSoup

# %%
soup = BeautifulSoup(web.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="initial-scale=1.0, width=device-width" name="viewport"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/e7f6f1cdcd818262.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/><link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-0aabb03b8344b3d6.js" rel="preload"/><script async="" src="/_next/static/chunks/fd9d1056-6f4a001df26bd3d5.js"></script><script async="" src="/_next/static/chunks/7023-c02abf1b325e8331.js"></script><script async="" src="/_next/static/chunks/main-app-55bbd77d79f9187f.js"></script><script async="" src="/_next/static/chunks/13b76428-3a27edfd28c29f16.js"></script><script async="" src="/_next/static/chunks/870fdd6f-22711ca73e9ce48a.js"></script><script async="" src="/_next/static/chunks/aaea2bcf-ac1e4c598ac1115c.js"></script><script async="" src="/_next/static/chunks/69b09407-69006f1471a14c8b.js"></script><script async="" src="/_next/static/chunks/8173-f78e64cf3ff15bed.js"></script><script async="" src="/_next/static/chunks/231-601727ca8ccadf3a.js"></script><script async="" src="/_next/static/chunks/5301-b82a5f7b91b0094b.js"></script><script async="" src="/_next/static/chunks/1170-8492a58d91125314.js"></script><script async="" src="/_next/static/chunks/1232-875777db31fa6c13.js"></script><script async="" src="/_next/static/chunks/661-b8a309bacf0d3fee.js"></script><script async="" src="/_next/static/chunks/6920-e5bb9f3f41bd5fb1.js"></script><script async="" src="/_next/static/chunks/9589-d466380df4176dbb.js"></script><script async="" src="/_next/static/chunks/6474-dcd34a28ef6504c6.js"></script><script async="" src="/_next/static/chunks/3463-6d2676f3b74b354b.js"></script><script async="" src="/_next/static/chunks/6580-c9fd45efaf19adb4.js"></script><script async="" src="/_next/static/chunks/4443-9f9caae06b52512e.js"></script><script async="" src="/_next/static/chunks/5839-7b6c7a7101086a3b.js"></script><script async="" src="/_next/static/chunks/4048-8f73d5ca51e6a542.js"></script><script async="" src="/_next/static/chunks/9118-c498f085639a9603.js"></script><script async="" src="/_next/static/chunks/4255-3c64d45fb7eb9d2d.js"></script><script async="" src="/_next/static/chunks/2666-5dc0ca817461abc5.js"></script><script async="" src="/_next/static/chunks/3117-da16f3894d61959b.js"></script><script async="" src="/_next/static/chunks/4919-e4d1afa56f216042.js"></script><script async="" src="/_next/static/chunks/app/layout-05de045e55259322.js"></script><script async="" src="/_next/static/chunks/app/not-found-c9d0c767ebbbdd37.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3L0ZF56S68"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-10998233603"></script><script async="" src="/_next/static/chunks/3153-6e9a067002404e99.js"></script><script async="" src="/_next/static/chunks/3210-0ce9c3ece71d053e.js"></script><script async="" src="/_next/static/chunks/app/page-85df5481d7287c45.js"></script><meta content="course" property="og:type"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link as="font" crossorigin="anonymous" href="/fonts/Neulis-Regular.otf" rel="preload" type="font/otf"/><title>WsCube Tech: Online Certification Courses &amp; Live Training</title><meta content="WsCube Tech offers the best job-oriented online certification courses in digital marketing, web/app development, cyber security, data science &amp; more." name="description"/><link href="https://www.wscubetech.com/" r ...
#                   window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#               gtag('config', 'G-3L0ZF56S68');
#                 </script><script>
#               (function(w,d,s,l,i){
#                 w[l]=w[l]||[];
#                 w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});
#                 var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#                 j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;
#                 f.parentNode.insertBefore(j,f);
#               })(window,document,'script','dataLayer','GTM-52JC74P');
#                 </script><script>
#             window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#               gtag('config', 'AW-10998233603');
#                 </script><script nomodule="" src="/_next/static/chunks/polyfills-78c92fac7aa8fdd8.js"></script></head><body><noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-52JC74P" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript><div class="Toastify"></div><header class="header-section d-none d-lg-block" style="overflow:visible"><div class="header-position px-2xl-55 px-xl-32 px-20 w-100" style="height:72px;display:flex;align-items:center;width:100%;box-sizing:border-box;overflow:visible;position:relative"><a class="flex-shrink-0 me-0 position-relative lpt-logo" href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" class="max-w-xl-139 max-w-80" data-nimg="1" decoding="async" height="56" loading="lazy" src=" https://deen3evddmddt.cloudfront.net/static/images/ws-cube-white-logo.svg" style="color:transparent;max-height:56px;height:auto" width="139"/></span></a><div class="header-nav-wrapper w-100" style="margin-left:30px;display:flex;align-items:center;gap:6px;flex-wrap:nowrap"><div style="position:static;display:flex;align-items:center;gap:6px"><div class="online-programs-mega-menu"><button class="white-fill-btn min-h-40 py-8 px-xl-15 px-12 rounded-8 fs-14 fw-400 lh-24 d-flex align-items-center user-dropdown-btn cursor-pointer" style="border-width:1px;height:40px;white-space:nowrap"><span class="mr-8">Online Programs</span><svg class="menu-arrow" fill="none" height="20" viewbox="0 0 21 20" width="21"><path d="M6.33594 10.8333L10.5026 15L14.6693 10.8333M6.33594 5L10.5026 9.16667L14.6693 5" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg></button></div><div class="online-programs-mega-menu"><div class="cursor-pointer white-fill-btn skills-toggle min-h-40 py-8 px-2xl-20 px-lg-16 px-12 rounded-8 fs-14 fw-400 lh-24 d-flex align-items-center user-dropdown-btn border-0" style="height:40px;white-space:nowrap"><span class="mr-8">On Campus Programs</span><svg aria-hidden="true" class="svg-inline--fa fa-chevron-down menu-arrow" data-icon="chevron-down" data-prefix="fas" focusable="false" height="10" role="img" viewbox="0 0 512 512" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M233.4 406.6c12.5 12.5 32.8 12.5 45.3 0l192-192c12.5-12.5 12.5-32.8 0-45.3s-32.8-12.5-45.3 0L256 338.7 86.6 169.4c-12.5-12.5-32.8-12.5-45.3 0s-12.5 32.8 0 45.3l192 192z" fill="currentColor"></path></svg></div></div></div><a class="nav-items-link cursor-pointer" href="/events"><span class="text-color-2 fs-14 fw-400 lh-24 d-flex align-items-center px-12 apply-as-mentor-btn" style="height:40px;white-space:nowrap">Masterclass</span></a><a class="nav-items-link cursor-pointer" href="/resources"><span class="text-color-2 fs-14 fw-400 lh-24 d-flex align-items-center px-12 apply-as-mentor-btn" style="height:40px;white-space:nowrap">Free Resources</span></a><a class="nav-items-link cursor-pointer" href="/alumni"><span class="text-color-2 fs-14 fw-400 lh-24 d-flex align-items-center px-12 apply-as-mentor-btn" style="height:40px;white-space:nowrap">Alumni</span></a><div class="user-btn-wrapper d-flex align-items-center ms-auto"></div></div></div></header><header class="d-lg-none mobile-header position-absolute w-100"><div class="h-size-66 w-100 mobile-navbar transation-1 d-flex justify-content-between align-items-center px-16 bg-transparent"><a class="d-block" href="/"><img alt="logo" data-nimg="1" decoding="async" height="52" loading="lazy" src="https://deen3evddmddt.cloudfront.net/static/images/ws-cube-white-logo.svg" style="color:transparent" width="106"/></a><div class="d-flex align-items-center"><button class="white-fill-btn min-h-32 py-7 pl-12 pr-8 rounded-8 fs-xl-16 fs-12 fw-400 lh-18 d-flex align-items-center user-dropdown-btn cursor-pointer mr-16" style="border-width:1px"><span class="mr-8">Programs</span><svg class="menu-arrow" fill="none" height="16" viewbox="0 0 21 20" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M6.33594 10.8333L10.5026 15L14.6693 10.8333M6.33594 5L10.5026 9.16667L14.6693 5" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg></button><button class="p-0 bg-transparent border-0 outline-none shadow-none"><img alt="menu" data-nimg="1" d ...

# %%
soup.name
# Out:
# '[document]'

# %%
soup.title
# Out:
# <title>WsCube Tech: Online Certification Courses &amp; Live Training</title>

# %%
soup.body
# Out:
# <body><noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-52JC74P" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript><div class="Toastify"></div><header class="header-section d-none d-lg-block" style="overflow:visible"><div class="header-position px-2xl-55 px-xl-32 px-20 w-100" style="height:72px;display:flex;align-items:center;width:100%;box-sizing:border-box;overflow:visible;position:relative"><a class="flex-shrink-0 me-0 position-relative lpt-logo" href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" class="max-w-xl-139 max-w-80" data-nimg="1" decoding="async" height="56" loading="lazy" src=" https://deen3evddmddt.cloudfront.net/static/images/ws-cube-white-logo.svg" style="color:transparent;max-height:56px;height:auto" width="139"/></span></a><div class="header-nav-wrapper w-100" style="margin-left:30px;display:flex;align-items:center;gap:6px;flex-wrap:nowrap"><div style="position:static;display:flex;align-items:center;gap:6px"><div class="online-programs-mega-menu"><button class="white-fill-btn min-h-40 py-8 px-xl-15 px-12 rounded-8 fs-14 fw-400 lh-24 d-flex align-items-center user-dropdown-btn cursor-pointer" style="border-width:1px;height:40px;white-space:nowrap"><span class="mr-8">Online Programs</span><svg class="menu-arrow" fill="none" height="20" viewbox="0 0 21 20" width="21"><path d="M6.33594 10.8333L10.5026 15L14.6693 10.8333M6.33594 5L10.5026 9.16667L14.6693 5" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg></button></div><div class="online-programs-mega-menu"><div class="cursor-pointer white-fill-btn skills-toggle min-h-40 py-8 px-2xl-20 px-lg-16 px-12 rounded-8 fs-14 fw-400 lh-24 d-flex align-items-center user-dropdown-btn border-0" style="height:40px;white-space:nowrap"><span class="mr-8">On Campus Programs</span><svg aria-hidden="true" class="svg-inline--fa fa-chevron-down menu-arrow" data-icon="chevron-down" data-prefix="fas" focusable="false" height="10" role="img" viewbox="0 0 512 512" width="10" xmlns="http://www.w3.org/2000/svg"><path d="M233.4 406.6c12.5 12.5 32.8 12.5 45.3 0l192-192c12.5-12.5 12.5-32.8 0-45.3s-32.8-12.5-45.3 0L256 338.7 86.6 169.4c-12.5-12.5-32.8-12.5-45.3 0s-12.5 32.8 0 45.3l192 192z" fill="currentColor"></path></svg></div></div></div><a class="nav-items-link cursor-pointer" href="/events"><span class="text-color-2 fs-14 fw-400 lh-24 d-flex align-items-center px-12 apply-as-mentor-btn" style="height:40px;white-space:nowrap">Masterclass</span></a><a class="nav-items-link cursor-pointer" href="/resources"><span class="text-color-2 fs-14 fw-400 lh-24 d-flex align-items-center px-12 apply-as-mentor-btn" style="height:40px;white-space:nowrap">Free Resources</span></a><a class="nav-items-link cursor-pointer" href="/alumni"><span class="text-color-2 fs-14 fw-400 lh-24 d-flex align-items-center px-12 apply-as-mentor-btn" style="height:40px;white-space:nowrap">Alumni</span></a><div class="user-btn-wrapper d-flex align-items-center ms-auto"></div></div></div></header><header class="d-lg-none mobile-header position-absolute w-100"><div class="h-size-66 w-100 mobile-navbar transation-1 d-flex justify-content-between align-items-center px-16 bg-transparent"><a class="d-block" href="/"><img alt="logo" data-nimg="1" decoding="async" height="52" loading="lazy" src="https://deen3evddmddt.cloudfront.net/static/images/ws-cube-white-logo.svg" style="color:transparent" width="106"/></a><div class="d-flex align-items-center"><button class="white-fill-btn min-h-32 py-7 pl-12 pr-8 rounded-8 fs-xl-16 fs-12 fw-400 lh-18 d-flex align-items-center user-dropdown-btn cursor-pointer mr-16" style="border-width:1px"><span class="mr-8">Programs</span><svg class="menu-arrow" fill="none" height="16" viewbox="0 0 21 20" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M6.33594 10.8333L10.5026 15L14.6693 10.8333M6.33594 5L10.5026 9.16667L14.6693 5" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></path></svg></button><button class="p-0 bg-transparent border-0 outline-none shadow-none"><img alt="menu" data-nimg="1" d ...

# %%
soup.head
# Out:
# <head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="initial-scale=1.0, width=device-width" name="viewport"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/e7f6f1cdcd818262.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/><link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-0aabb03b8344b3d6.js" rel="preload"/><script async="" src="/_next/static/chunks/fd9d1056-6f4a001df26bd3d5.js"></script><script async="" src="/_next/static/chunks/7023-c02abf1b325e8331.js"></script><script async="" src="/_next/static/chunks/main-app-55bbd77d79f9187f.js"></script><script async="" src="/_next/static/chunks/13b76428-3a27edfd28c29f16.js"></script><script async="" src="/_next/static/chunks/870fdd6f-22711ca73e9ce48a.js"></script><script async="" src="/_next/static/chunks/aaea2bcf-ac1e4c598ac1115c.js"></script><script async="" src="/_next/static/chunks/69b09407-69006f1471a14c8b.js"></script><script async="" src="/_next/static/chunks/8173-f78e64cf3ff15bed.js"></script><script async="" src="/_next/static/chunks/231-601727ca8ccadf3a.js"></script><script async="" src="/_next/static/chunks/5301-b82a5f7b91b0094b.js"></script><script async="" src="/_next/static/chunks/1170-8492a58d91125314.js"></script><script async="" src="/_next/static/chunks/1232-875777db31fa6c13.js"></script><script async="" src="/_next/static/chunks/661-b8a309bacf0d3fee.js"></script><script async="" src="/_next/static/chunks/6920-e5bb9f3f41bd5fb1.js"></script><script async="" src="/_next/static/chunks/9589-d466380df4176dbb.js"></script><script async="" src="/_next/static/chunks/6474-dcd34a28ef6504c6.js"></script><script async="" src="/_next/static/chunks/3463-6d2676f3b74b354b.js"></script><script async="" src="/_next/static/chunks/6580-c9fd45efaf19adb4.js"></script><script async="" src="/_next/static/chunks/4443-9f9caae06b52512e.js"></script><script async="" src="/_next/static/chunks/5839-7b6c7a7101086a3b.js"></script><script async="" src="/_next/static/chunks/4048-8f73d5ca51e6a542.js"></script><script async="" src="/_next/static/chunks/9118-c498f085639a9603.js"></script><script async="" src="/_next/static/chunks/4255-3c64d45fb7eb9d2d.js"></script><script async="" src="/_next/static/chunks/2666-5dc0ca817461abc5.js"></script><script async="" src="/_next/static/chunks/3117-da16f3894d61959b.js"></script><script async="" src="/_next/static/chunks/4919-e4d1afa56f216042.js"></script><script async="" src="/_next/static/chunks/app/layout-05de045e55259322.js"></script><script async="" src="/_next/static/chunks/app/not-found-c9d0c767ebbbdd37.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3L0ZF56S68"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-10998233603"></script><script async="" src="/_next/static/chunks/3153-6e9a067002404e99.js"></script><script async="" src="/_next/static/chunks/3210-0ce9c3ece71d053e.js"></script><script async="" src="/_next/static/chunks/app/page-85df5481d7287c45.js"></script><meta content="course" property="og:type"/><link href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link as="font" crossorigin="anonymous" href="/fonts/Neulis-Regular.otf" rel="preload" type="font/otf"/><title>WsCube Tech: Online Certification Courses &amp; Live Training</title><meta content="WsCube Tech offers the best job-oriented online certification courses in digital marketing, web/app development, cyber security, data science &amp; more." name="description"/><link href="https://www.wscubetech.com/" rel="canonical"/> ...
#                   window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#               gtag('config', 'G-3L0ZF56S68');
#                 </script><script>
#               (function(w,d,s,l,i){
#                 w[l]=w[l]||[];
#                 w[l].push({'gtm.start':
#                 new Date().getTime(),event:'gtm.js'});
#                 var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#                 j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;
#                 f.parentNode.insertBefore(j,f);
#               })(window,document,'script','dataLayer','GTM-52JC74P');
#                 </script><script>
#             window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#               gtag('config', 'AW-10998233603');
#                 </script><script nomodule="" src="/_next/static/chunks/polyfills-78c92fac7aa8fdd8.js"></script></head>

# %%
soup.find("title")
# Out:
# <title>WsCube Tech: Online Certification Courses &amp; Live Training</title>

# %%
soup.find('p')
soup.find_all('p')
# Out:
# [<p class="fs-18 lh-24 fw-400 text-color-1 mb-16">Online Programs</p>,
#  <p class="fs-18 lh-24 fw-400 mb-16 text-color-1">On-Campus Programs</p>,
#  <p class="text-color-19 fs-12 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>]

# %% [markdown]
# # Comments

# %%
com = soup.p.string
com
# Out:
# 'Online Programs'

# %%
# prettify manage all the data in a structred way.
soup.p.prettify()
# Out:
# '<p class="fs-18 lh-24 fw-400 text-color-1 mb-16">\n Online Programs\n</p>\n'
